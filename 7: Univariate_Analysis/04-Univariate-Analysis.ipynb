# %% [markdown]
# # **Univariate Analysis**
# Uni means one and variate means variable, so in univariate analysis, there is only one dependable variable. The objective of univariate analysis is to derive the data, define and summarize it, and analyze the pattern present in it. In a dataset, it explores each variable separately. It is possible for two kinds of variables- Categorical and Numerical.

# %% [markdown]
# Some patterns that univariate analysis can easily identify include Central Tendency (mean, mode, and median), Dispersion (range, variance), Quartiles (interquartile range), and Standard Deviation.
#
# # **Univariate data can be described through:**
#
# Frequency Distribution Tables
# The frequency distribution table reflects how often an occurrence has taken place in the data. It gives a brief idea of the data and makes it easier to find patterns.

# %% [markdown]
# The following types of charts works well with univariate analysis:
# Histogram, Bar Chart, Box Plot, Pie charts

# %% [markdown]
# # **Histograms**
#
# A histogram is a graphical representation used in statistics to show the distribution of continuous numerical data. The data is grouped into class intervals (bins), and the height of each bar shows the frequency of values.
#
# A histogram helps us understand the shape of the data, such as peaks, spread, and whether the data is symmetric or skewed.

# %% [markdown]
# # **Bar Chart**
#
# A bar plot (or bar chart) is a graphical representation that uses rectangular bars to compare different categories. The height or length of each bar corresponds to the value it represents.

# %% [markdown]
# # **Box Plot/Whisker Plot**
# A Box Plot (or Whisker plot) display the summary of a data set, including minimum, first quartile, median, third quartile and maximum. it consists of a box from the first quartile to the third quartile, with a vertical line at the median. the x-axis denotes the data to be plotted while the y-axis shows the frequency distribution.
# ![what-is-a-boxplot.webp](data:image/webp;base64,...)

# %% [markdown]
# # **Pie Chart** (Univariate Categorical Data)
# A Pie Chart is a circular chart divided into slices, where each slice represents the proportion (percentage) of each category in a dataset.

# %% [markdown]
# ## 1. Import Libraries and load dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("global air pollution dataset.csv")

df.head()
# Out:
#               Country              City  AQI Value AQI Category  CO AQI Value  \
# 0  Russian Federation        Praskoveya         51     Moderate             1
# 1              Brazil  Presidente Dutra         41         Good             1
# 2               Italy   Priolo Gargallo         66     Moderate             1
# 3              Poland         Przasnysz         34         Good             1
# 4              France          Punaauia         22         Good             0
#
#   CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 0            Good               36               Good              0
# 1            Good                5               Good              1
# 2            Good               39               Good              2
# 3            Good               34               Good              0
# 4            Good               22               Good              0
#
#   NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category
# ...

# %% [markdown]
# # **Histogram**

# %% [markdown]
# Histogram 1: AQI Value

# %%
plt.figure()
plt.hist(df['AQI Value'], bins=20)
plt.title("Distribution of AQI Value")
plt.xlabel("AQI Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **For the below histogram with bell curve we are not using dataframe created above. We have used randomly generated numpy array.**

# %%
# Generate normal distributed data
data = np.random.normal(loc=0, scale=1, size=1000)

# Mean and standard deviation
mean = statistics.mean(data)
sd = statistics.stdev(data)

# X values for smooth curve
x = np.linspace(min(data), max(data), 200)

# Plot histogram
plt.hist(data, bins=20, density=True, alpha=0.6)

# Plot normal distribution curve
plt.plot(x, norm.pdf(x, mean, sd), linewidth=2)

plt.title("Normal Distribution with Histogram")
plt.show()

# %% [markdown]
# Histogram 2: PM2.5 AQI Value

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics

data = df['PM2.5 AQI Value']

plt.figure()

# Histogram
counts, bins, _ = plt.hist(data, bins=20, alpha=0.6)

# Mean and standard deviation from dataset
mean = statistics.mean(data)
sd = statistics.stdev(data)

# X values aligned with histogram
x_axis = np.linspace(min(data), max(data), 200)

# Scale PDF to histogram frequency
bin_width = bins[1] - bins[0]
y = norm.pdf(x_axis, mean, sd) * len(data) * bin_width

# Plot bell curve
plt.plot(x_axis, y, linewidth=2)

plt.title("Distribution of PM2.5 AQI Value")
plt.xlabel("PM2.5 AQI Value")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# # **Box Plots**

# %%
plt.figure()
plt.boxplot(df['NO2 AQI Value'], showfliers=False)
plt.title("Boxplot of NO2 AQI Value")
plt.ylabel("NO2 AQI Value")
plt.show()

# %%
import numpy as np

plt.figure()
plt.boxplot(np.log1p(df['PM2.5 AQI Value']))
plt.title("Boxplot of Log PM2.5 AQI Value")
plt.ylabel("Log(PM2.5 AQI Value)")
plt.show()

# %% [markdown]
# # **Bar Charts (Categorical Variables)**

# %%
plt.figure()
df['AQI Category'].value_counts().plot(kind='bar')
plt.title("AQI Category Distribution")
plt.xlabel("AQI Category")
plt.ylabel("Count")
plt.show()

# %%
plt.figure()
df['Ozone AQI Category'].value_counts().plot(kind='bar')
plt.title("Ozone AQI Category Distribution")
plt.xlabel("Category")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # **Pie Chart**

# %%
plt.figure()
df['NO2 AQI Category'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("NO2 AQI Category Percentage")
plt.ylabel("")
plt.show()

# %%
plt.figure()
df['AQI Category'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Overall AQI Category Percentage")
plt.ylabel("")
plt.show()
